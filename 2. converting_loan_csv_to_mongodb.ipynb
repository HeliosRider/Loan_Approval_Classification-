# %%
import pandas as pd
from pathlib import Path

# %%
# Define the file path
file_path = Path("Resources/clean_loan_data.csv")

# Read the CSV file into a DataFrame
loans_df = pd.read_csv(file_path)

# Display the DataFrame
loans_df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44990          27          male        Associate          47971
# 44991          37        female        Associate          65800
# 44992          33          male        Associate          56942
# 44993          29          male         Bachelor          33164
# 44994          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# ...

# %% [markdown]
# ## Creating the "loan_data_db" database in mongodb
# Load

# %%
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# create the database
loandb = myclient["loan_data_db"]

# %%
 #Create a collection called "loans":
loans = loandb["loans"]

# %%
# Convert DataFrame to list of dictionaries
list_of_dicts = loans_df.to_dict(orient='records')
list_of_dicts[0]
# Out:
# {'person_age': 22,
#  'person_gender': 'female',
#  'person_education': 'Master',
#  'person_income': 71948,
#  'person_emp_exp': 0,
#  'person_home_ownership': 'RENT',
#  'loan_amnt': 35000,
#  'loan_intent': 'PERSONAL',
#  'loan_int_rate': 16.02,
#  'loan_percent_income': 0.49,
#  'cb_person_cred_hist_length': 3,
#  'credit_score': 561,
#  'previous_loan_defaults_on_file': 'No',
#  'loan_status': 1}

# %%
#load the data into loan_data_db
results=loans.insert_many(list_of_dicts)

# %%
# list all the databases
print(myclient.list_database_names())
# Out:
# ['Autosaurus', 'admin', 'classDB', 'config', 'epa', 'loan_data_db', 'local', 'merteorite_landings_db', 'petsitly_marketing', 'petsitly_marketing5', 'travel_db', 'uk_food']

# %%
#print the first element 
loans.find_one()
# Out:
# {'_id': ObjectId('67b88e17a7986ac580aaa411'),
#  'person_age': 22,
#  'person_gender': 'female',
#  'person_education': 'Master',
#  'person_income': 71948,
#  'person_emp_exp': 0,
#  'person_home_ownership': 'RENT',
#  'loan_amnt': 35000,
#  'loan_intent': 'PERSONAL',
#  'loan_int_rate': 16.02,
#  'loan_percent_income': 0.49,
#  'cb_person_cred_hist_length': 3,
#  'credit_score': 561,
#  'previous_loan_defaults_on_file': 'No',
#  'loan_status': 1}

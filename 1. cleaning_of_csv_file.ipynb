# %% [markdown]
# # Loan Application
# ---
#
# ## Starter Code to Import Libraries and Load the loan data CSV

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# %%
# Define the file path
file_path = Path("Resources/clean_loan_data_db.csv") # file cleaned in the mongo database 

# Read the CSV file into a DataFrame
loans_df = pd.read_csv(file_path)

# Display the DataFrame
loans_df
# Out:
#                             _id  person_age person_gender person_education  \
# 0      67b7e45ba850d64d6f8b4678          22        female           Master
# 1      67b7e45ba850d64d6f8b4679          21        female      High School
# 2      67b7e45ba850d64d6f8b467a          25        female      High School
# 3      67b7e45ba850d64d6f8b467b          23        female         Bachelor
# 4      67b7e45ba850d64d6f8b467c          24          male           Master
# ...                         ...         ...           ...              ...
# 44990  67b7e45ca850d64d6f8bf63b          27          male        Associate
# 44991  67b7e45ca850d64d6f8bf63c          37        female        Associate
# 44992  67b7e45ca850d64d6f8bf63d          33          male        Associate
# 44993  67b7e45ca850d64d6f8bf63e          29          male         Bachelor
# 44994  67b7e45ca850d64d6f8bf63f          24          male      High School
#
#        person_income  person_emp_exp person_home_ownership  loan_amnt  \
# 0              71948               0                  RENT      35000
# 1              12282               0                   OWN       1000
# 2              12438               3              MORTGAGE       5500
# 3              79753               0                  RENT      35000
# 4              66135               1                  RENT      35000
# ...              ...             ...                   ...        ...
# 44990          47971               6                  RENT      15000
# 44991          65800              17                  RENT       9000
# 44992          56942               7                  RENT       2771
# 44993          33164               4                  RENT      12000
# 44994          51609               1                  RENT       6665
#
#              loan_intent  loan_int_rate  loan_percent_income  \
# 0               PERSONAL          16.02                 0.49
# 1              EDUCATION          11.14                 0.08
# 2                MEDICAL          12.87                 0.44
# 3                MEDICAL          15.23                 0.44
# 4                MEDICAL          14.27                 0.53
# ...                  ...            ...                  ...
# 44990            MEDICAL          15.66                 0.31
# 44991    HOMEIMPROVEMENT          14.07                 0.14
# 44992  DEBTCONSOLIDATION          10.02                 0.05
# 44993          EDUCATION          13.23                 0.36
# 44994  DEBTCONSOLIDATION          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score  \
# 0                               3           561
# 1                               2           504
# 2                               3           635
# 3                               2           675
# 4                               4           586
# ...                           ...           ...
# 44990                           3           645
# 44991                          11           621
# 44992                          10           668
# 44993                           6           604
# 44994                           3           628
#
#       previous_loan_defaults_on_file  loan_status
# 0                                 No            1
# 1                                Yes            0
# 2                                 No            1
# 3                                 No            1
# 4                                 No            1
# ...                              ...          ...
# 44990                             No            1
# 44991                             No            1
# 44992                             No            1
# 44993                             No            1
# 44994                             No            1
#
# [44995 rows x 15 columns]

# %%
# finding the info
loans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44995 entries, 0 to 44994
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   _id                             44995 non-null  object
#  1   person_age                      44995 non-null  int64
#  2   person_gender                   44995 non-null  object
#  3   person_education                44995 non-null  object
#  4   person_income                   44995 non-null  int64
#  5   person_emp_exp                  44995 non-null  int64
#  6   person_home_ownership           44995 non-null  object
#  7   loan_amnt                       44995 non-null  int64
#  8   loan_intent                     44995 non-null  object
#  9   loan_int_rate                   44995 non-null  float64
#  10  loan_percent_income             44995 non-null  float64
#  11  cb_person_cred_hist_length      44995 non-null  int64
#  12  credit_score                    44995 non-null  int64
#  13  previous_loan_defaults_on_file  44995 non-null  object
#  14  loan_status                     44995 non-null  int64
# dtypes: float64(2), int64(7), object(6)
# memory usage: 5.1+ MB

# %%
#Dropping all rows that may missing information

loans_clean_df = loans_df.dropna(how='any')
loans_clean_df
# Out:
#                             _id  person_age person_gender person_education  \
# 0      67b7e45ba850d64d6f8b4678          22        female           Master
# 1      67b7e45ba850d64d6f8b4679          21        female      High School
# 2      67b7e45ba850d64d6f8b467a          25        female      High School
# 3      67b7e45ba850d64d6f8b467b          23        female         Bachelor
# 4      67b7e45ba850d64d6f8b467c          24          male           Master
# ...                         ...         ...           ...              ...
# 44990  67b7e45ca850d64d6f8bf63b          27          male        Associate
# 44991  67b7e45ca850d64d6f8bf63c          37        female        Associate
# 44992  67b7e45ca850d64d6f8bf63d          33          male        Associate
# 44993  67b7e45ca850d64d6f8bf63e          29          male         Bachelor
# 44994  67b7e45ca850d64d6f8bf63f          24          male      High School
#
#        person_income  person_emp_exp person_home_ownership  loan_amnt  \
# 0              71948               0                  RENT      35000
# 1              12282               0                   OWN       1000
# 2              12438               3              MORTGAGE       5500
# 3              79753               0                  RENT      35000
# 4              66135               1                  RENT      35000
# ...              ...             ...                   ...        ...
# 44990          47971               6                  RENT      15000
# 44991          65800              17                  RENT       9000
# 44992          56942               7                  RENT       2771
# 44993          33164               4                  RENT      12000
# 44994          51609               1                  RENT       6665
#
#              loan_intent  loan_int_rate  loan_percent_income  \
# 0               PERSONAL          16.02                 0.49
# 1              EDUCATION          11.14                 0.08
# 2                MEDICAL          12.87                 0.44
# 3                MEDICAL          15.23                 0.44
# 4                MEDICAL          14.27                 0.53
# ...                  ...            ...                  ...
# 44990            MEDICAL          15.66                 0.31
# 44991    HOMEIMPROVEMENT          14.07                 0.14
# 44992  DEBTCONSOLIDATION          10.02                 0.05
# 44993          EDUCATION          13.23                 0.36
# 44994  DEBTCONSOLIDATION          17.05                 0.13
#
#        cb_person_cred_hist_length  credit_score  \
# 0                               3           561
# 1                               2           504
# 2                               3           635
# 3                               2           675
# 4                               4           586
# ...                           ...           ...
# 44990                           3           645
# 44991                          11           621
# 44992                          10           668
# 44993                           6           604
# 44994                           3           628
#
#       previous_loan_defaults_on_file  loan_status
# 0                                 No            1
# 1                                Yes            0
# 2                                 No            1
# 3                                 No            1
# 4                                 No            1
# ...                              ...          ...
# 44990                             No            1
# 44991                             No            1
# 44992                             No            1
# 44993                             No            1
# 44994                             No            1
#
# [44995 rows x 15 columns]

# %%
# The above codes were written to ensure the loan_data.csv is clean
# The codes revealed that the loan_data.csv is a clean data set 
# Remove person age over 100
